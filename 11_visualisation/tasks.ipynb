# %% [markdown]
# # Практическое задание: Аналитика магазинов «Пятёрочка»
#
# **Контекст:**
# X5 Tech предоставила выгрузку данных по магазинам торговой сети «Пятёрочка» за один календарный год.
# Датасет содержит информацию о магазинах: трафик, средний чек, количество школ/остановок рядом, данные о конкурентах.
# Описание [находится здесь](https://dano.hse.ru/mirror/pubs/share/1102761036.pdf)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_theme(style="whitegrid")

# %% [markdown]
# ### 1. Загрузка данных
#
# 1. Импортируйте `pandas`.
# 2. Загрузите файл по ссылке: `https://dano.hse.ru/mirror/pubs/share/1102761259.xlsx` (используйте функцию `read_excel`).
# 3. Выведите первые 5 строк и информацию о типах данных (`.info()`).

# %%
# Твой код здесь

# %% [markdown]
# ### 2. Анализ распределений (Boxplot & Histplot)
# Есть ли выбросы в количестве сотрудников (`Количество сотрудников`) или в трафике?
#
# Построй **Boxplot** (ящик с усами) для колонки `Трафик (модифицирован)`.
# Рядом (в новой ячейке) построй **Histplot** для этой же колонки.

# %%
# Твой код здесь

# %% [markdown]
# ### 3. Сравнение категорий (Violin Plot)
# Влияет ли возраст магазина на средний чек?
#
# Построй **Violin Plot**:
# - Ось X: `Дата открытия, категориальный` (старые/новые)
# - Ось Y: `Средний чек (модифицирован)`
#
# Видно ли разницу в распределении?

# %%
# Твой код здесь

# %% [markdown]
# ### 4. Корреляционная матрица (Heatmap)
# Какие внешние факторы сильнее всего влияют на успех магазина?
#
# 1. Создай переменную `corr`, куда запиши матрицу корреляций (`df.corr(numeric_only=True)`).
# 2. Визуализируй её с помощью `sns.heatmap`.
# 3. Поставь `annot=True` и настрой размер графика (`figsize`), чтобы цифры читались.

# %%
# Твой код здесь

# %% [markdown]
# ### 5. Продвинутый Matplotlib: Subplots
# Сравни Трафик в разных регионах и Трафик в зависимости от размера площади, расположив два графика **рядом** (слева и справа).
#
# 1. Создай `fig, axes = plt.subplots(1, 2, figsize=(15, 6))`.
# 2. На `axes[0]` нарисуй **Barplot**: X = Регион, Y = Трафик.
# 3. На `axes[1]` нарисуй **Boxplot**: X = Торговая площадь, Y = Трафик.
# 4. Не забудь повернуть подписи регионов, если нужно.

# %%
# Твой код здесь
