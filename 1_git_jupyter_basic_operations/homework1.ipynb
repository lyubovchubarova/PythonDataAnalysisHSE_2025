# %% [markdown]
# Вам нужно
#
# 1) Сделать себе репозиторий для домашнего задания на гитхабе, и сделать его приватным (синий радиобаттон на Private при создании)
# ![вот так](private.png)
#
# 2) Добавить профиль lyubovchubarova в collaborators
#
# 3) NB! Все домашки сдаем в отдельных папках в тетрадках с ЯСНЫМИ НАЗВАНИЯМИ. Название папки - 1 цифра, обозначающая номер домашнего задания
#
# Вот пример хорошей структуры репозитория для ДЗ
# ```
# LyceumHSE_DA_hw/
# ├── 1/
# │   ├── jupyter_screen.png
# │   └── hw1.ipynb
# ├── 2/
# │   └── hw2.ipynb
# ├── 3/
# │   └── hw3.ipynb
# └── 4/
#     └── hw4.ipynb
# ```
# **Задача 1:** поместить в репозиторий скриншот из командной строки, который подтверждает, что у вас установлен jupyter notebook. Про формат jupyter и как его установить можно [почитать здесь](https://practicum.yandex.ru/blog/chto-takoe-jupyter-notebook/), это такая среда для представления кода. Эта домашка тоже сделана в jupyter ноутбуке =)
#
# **Задача 2:**  поместить в репозиторий jupyter-тетрадь, в которой вы
#
#    - проверяете свое текущее расположение в файловой системе
#    - идете на 1 уровень вверх
#    - создаете там папку
#    - проверяете, что папка создана
#    - удаляете папку
#    - проверяете что папка удалилась
#   NB! погуглите, как выполнять команды в командной строке из jupyter
#
# **Задача 3:**  в той же jupyter-тетради в отдельных ячейках напишите решения этих задач
# Помещайте текст задания перед решением, чтобы мне удобнее было проверять.
#
# - Найдите длину окружности с радиусом 28.4456 см. Примем, что пи равно 3.1415.
# - Найдите объём конуса с диаметром основания 10.752 см и высотой 5.102 см.
# - Определите, сколько лет/месяцев/недель/дней/часов/минут в 5394523242 секундах.
# - В московской Вышке 50925 студентов. Из них на ФГН учатся 3265. Сколько процентов студентов учится на других факультетах? Выведите на экран количество процентов с точностью до двух знаков после запятой (для этого надо погуглить).
# - Напишите код, который переводит целое число в строку, при том что его можно применить в любой системе счисления (опять надо погуглить).
#
#
# **Дедлайн 14 сентября в 23:59**
